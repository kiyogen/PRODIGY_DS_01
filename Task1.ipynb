# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data1.csv', skiprows = 4)
population = df['1960'].dropna()

plt.figure(figsize=(10,6))
plt.hist(np.log10(population), bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Country Populations in 2024')
plt.xlabel('Population')
plt.ylabel('Number of Countries')
plt.grid(True)
plt.show()
